# %%
from datasets import load_dataset

# %%
ds_path = "/home/gayapath/PROJECTS/dataset_cache/Riksarkivet___goteborgs_poliskammare_fore_1900_lines"

ds = load_dataset(ds_path)
# Out:
# Resolving data files:   0%|          | 0/117 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Loading dataset shards:   0%|          | 0/117 [00:00<?, ?it/s]

# %%
print(ds["train"][2]["transcription"])
# Out:
# År 1880.

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'transcription'],
#         num_rows: 357155
#     })
# })

# %%
ds["train"][2]
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=395x128>,
#  'transcription': 'År 1880.'}
